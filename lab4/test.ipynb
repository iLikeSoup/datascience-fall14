# %%
import pandas as pd

left1 = pd.DataFrame({'value': range(6)}, index=['a', 'b', 'a', 'a', 'b', 'c'])
right1 = pd.DataFrame({'group_val': [3.5, 7]}, index=['a', 'b'])

# %%
s1 = pd.Series([0, 1], index=['a', 'b'])
s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e'])
s3 = pd.Series([5, 6], index=['f', 'g'])

# %%
s4 = pd.concat([s1 * 5, s3])
s4
# Out:
# a    0
# b    5
# f    5
# g    6
# dtype: int64

# %%
s1
# Out:
# a    0
# b    1
# dtype: int64

# %%
s3
# Out:
# f    5
# g    6
# dtype: int64

# %%
import numpy as np

# %%
data = pd.DataFrame(np.arange(6).reshape((2, 3)), index=pd.Index(['Ohio', 'Colorado'], name='state'), columns=pd.Index(['one', 'two', 'three'], name='number'))

# %%
data
# Out:
# number    one  two  three
# state
# Ohio        0    1      2
# Colorado    3    4      5
#
# [2 rows x 3 columns]

# %%
import re

# %%
with open('cmsc.txt', 'r') as f:
    text = f.read()
classes = re.split('CMSC[\d]{3}', text)
del classes[0]

# %%
compile_courseNum = re.compile('CMSC[\d]{3}')
compile_sectionNum = re.compile('\n([\d]{4})')
compile_instructor = re.compile('\n((?:[A-Za-z-.:]+)(?: [A-Za-z-]+)+)')
compile_seats_open_waitlist = re.compile('Seats \(Total: ([\d]{1,3}), Open: ([\d]{1,3}), Waitlist: ([\d]{1,3})\)')
compile_days_time = re.compile('\n([MWFTuh]+) ([\d]{1,2}:[\d]{1,2}(?:a|p)m - [\d]{1,2}:[\d]{1,2}(?:a|p)m)')
compile_building_room = re.compile('\n([A-Z]{3})  ([\d]{4})')

courseNum = compile_courseNum.findall(text)
length = len(courseNum)
df = []
for i in range(length):
    sectionNum = compile_sectionNum.findall(classes[i])
    instructor = compile_instructor.findall(classes[i])
    seats_open_waitlist = compile_seats_open_waitlist.findall(classes[i])
    days_time = compile_days_time.findall(classes[i])
    building_room = compile_building_room.findall(classes[i])
    numRows = len(sectionNum) # length will be the same for any of the above (within the for loop)
    df_courseNum = pd.DataFrame({'Course No.': courseNum[i]}, index=[str(x) for x in range(numRows)])
    df_sectionNum = pd.DataFrame({'Section No.': sectionNum}, index=[str(x) for x in range(numRows)])
    df_instructor = pd.DataFrame({'Instructor': instructor}, index=[str(x) for x in range(numRows)])
    df_seats = pd.DataFrame({'Seats': [x[0] for x in seats_open_waitlist]}, index=[str(x) for x in range(numRows)])
    df_open = pd.DataFrame({'Open': [x[1] for x in seats_open_waitlist]}, index=[str(x) for x in range(numRows)])
    df_waitlist = pd.DataFrame({'Waitlist': [x[2] for x in seats_open_waitlist]}, index=[str(x) for x in range(numRows)])
    df_days = pd.DataFrame({'Days': [x[0] for x in days_time]}, index=[str(x) for x in range(numRows)])
    df_time = pd.DataFrame({'Time': [x[1] for x in days_time]}, index=[str(x) for x in range(numRows)])
    df_building = pd.DataFrame({'Building': [x[0] for x in building_room]}, index=[str(x) for x in range(numRows)])
    df_room = pd.DataFrame({'Room': [x[1] for x in building_room]}, index=[str(x) for x in range(numRows)])
    df.append(df_courseNum.join([df_sectionNum, df_instructor, df_seats, df_open, df_waitlist, df_days, df_time, df_building, df_room], 
                                how='outer'))
table = pd.concat([df[x] for x in range(length)], keys=[x for x in range(length)])
table.head()
# Out:
#     Course No. Section No.      Instructor Seats Open Waitlist  Days  \
# 0 0    CMSC100        0101  Charles Kassir    45    4        0     M
# 1 0    CMSC106        0101     Jianwu Wang    45    0        5  TuTh
# 2 0    CMSC131        0101      Evan Golub    31    0        0   MWF
#   1    CMSC131        0102      Evan Golub    31    0        0   MWF
#   2    CMSC131        0103      Evan Golub    31    1        0   MWF
#
#                  Time Building  Room
# 0 0   4:00pm - 4:50pm      CSI  2117
# 1 0  9:30am - 10:45am      CSI  2117
# 2 0   2:00pm - 2:50pm      CSI  1115
#   1   2:00pm - 2:50pm      CSI  1115
#   2   2:00pm - 2:50pm      CSI  1115
#
# [5 rows x 10 columns]

# %%
with open('worldcup.txt', 'r') as f:
    inp = f.read()
text = re.split('[A-Z]{3}\}', inp)
del text[0] # deletes extraneous part of text file

# %%
length = len(text)
coun = re.findall('([A-Z]{3})\}', inp)
comp_num = re.compile('\|([\d]) \(\[\[')
comp_years = re.compile('\|([\d]{4})\]')
df = []

for i in range(length):
    #print text[i]
    num = comp_num.findall(text[i])
    num = [int(x) for x in num]
    years = comp_years.findall(text[i])
    places = []
    counter = 1
    for a in range(len(num)):
        for b in range(num[a]):
            places.append(counter)
        counter += 1    
    my_ind = [str(x) for x in range(len(years))]
    df.append(pd.DataFrame({'Country': coun[i], 'Year': years, 'Place': places}, index=my_ind))
table = pd.concat([df[x] for x in range(length)], keys=[x for x in range(length)])
table.head()
# Out:
#     Country  Place  Year
# 0 0     BRA      1  1958
#   1     BRA      1  1962
#   2     BRA      1  1970
#   3     BRA      1  1994
#   4     BRA      1  2002
#
# [5 rows x 3 columns]

# %%
table.pivot('Country', 'Year', 'Place')
# Out:
# Year     1930  1934  1938  1950  1954  1958  1962  1966  1970  1974  1978  \
# Country
# ARG         2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     1
# AUT       NaN     2   NaN   NaN     1   NaN   NaN   NaN   NaN   NaN   NaN
# BEL       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# BRA       NaN   NaN     3     2   NaN     1     1   NaN     1     4     3
# BUL       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# CHI       NaN   NaN   NaN   NaN   NaN   NaN     1   NaN   NaN   NaN   NaN
# CRO       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ENG       NaN   NaN   NaN   NaN   NaN   NaN   NaN     1   NaN   NaN   NaN
# ESP       NaN   NaN   NaN     2   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FRA       NaN   NaN   NaN   NaN   NaN     3   NaN   NaN   NaN   NaN   NaN
# GER       NaN     3   NaN   NaN     1     4   NaN     2     3     1   NaN
# HUN       NaN   NaN     1   NaN     1   NaN   NaN   NaN   NaN   NaN   NaN
# ITA       NaN     1     1   NaN   NaN   NaN   NaN   NaN     2   NaN     4
# KOR       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# NED       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     1     1
# POL       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     1   NaN
# POR       NaN   NaN   NaN   NaN   NaN   NaN   NaN     1   NaN   NaN   NaN
# SWE       NaN   NaN     3     2   NaN     1   NaN   NaN   NaN   NaN   NaN
# TCH       NaN     1   NaN   NaN   NaN   NaN     1   NaN   NaN   NaN   NaN
# TUR       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# URS       NaN   NaN   NaN   NaN   NaN   NaN   NaN     1   NaN   NaN   NaN
# URU         1   NaN   NaN     1     2   NaN   NaN   NaN     2   NaN   NaN
# USA         1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# YUG         1   NaN   NaN   NaN   NaN   NaN     1   NaN   NaN   NaN   NaN
#
# Year     1982  1986  1990  1994  1998  2002  2006  2010  2014
# Country
# ARG       NaN     1     2   NaN   NaN   NaN   NaN   NaN     2
# AUT       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# BEL       NaN     1   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# BRA       NaN   NaN   NaN     1     2     1   NaN   NaN     4
# BUL       NaN   NaN   NaN     1   NaN   NaN   NaN   NaN   NaN
# CHI       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# CRO       NaN   NaN   NaN   NaN     1   NaN   NaN   NaN   NaN
# ENG       NaN   NaN     2   NaN   NaN   NaN   NaN   NaN   NaN
# ESP       NaN   NaN   NaN   NaN   NaN   NaN   NaN     1   NaN
# FRA         4     3   NaN   NaN     1   NaN     2   NaN   NaN
# GER         2     2     1   NaN   NaN     2     3     3     1
# HUN       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ITA         1   NaN     3     2   NaN   NaN     1   NaN   NaN
# KOR       NaN   NaN   NaN   NaN   NaN     1   NaN   NaN   NaN
# NED       NaN   NaN   NaN   NaN     3   NaN   NaN     1     2
# POL         1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# POR       NaN   NaN   NaN   NaN   NaN   NaN     2   NaN   NaN
# SWE       NaN   NaN   NaN     2   NaN   NaN   NaN   NaN   NaN
# TCH       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TUR       NaN   NaN   NaN   NaN   NaN     1   NaN   NaN   NaN
# URS       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# URU       NaN   NaN   NaN   NaN   NaN   NaN   NaN     2   NaN
# USA       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# YUG       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [24 rows x 20 columns]
