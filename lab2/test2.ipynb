# %%
import numpy as np
import pandas as pd

# %%
players = pd.read_csv('players.csv')

# %%
usa = players[players['country_id'] == 'USA']
a = usa['name'].str.extract('(^A.*)')
for name in a:
    if name is not np.nan:
        print(name)
# Out:
# Adam Nelson
# Alvin Harrison

# %%
usa
# Out:
#                                          name   player_id country_id  \
# 1    Aaron Peirsol                             PEIRSAAR01        USA
# 3    Adam Nelson                               NELSOADA01        USA
# 15   Allyson Felix                             FELIXALL01        USA
# 16   Alvin Harrison                            HARRIALV01        USA
# 17   Amanda Beard                              BEARDAMA01        USA
# 18   Amanda Weir                               WEIRAMA01         USA
# 19   Amy van Dyken                             VANDYAMY01        USA
# 25   Angelo Taylor                             TAYLOANG02        USA
# 30   Anthony Ervin                             ERVINANT01        USA
# 32   Antonio Pettigrew                         PETTIANT01        USA
# 40   BJ Bedford                                BEDFOBJ01         USA
# 43   Bernard Williams III                      WILLIBER02        USA
# 46   Brendan Hansen                            HANSEBRE01        USA
# ...

# %%
s = players[players['country_id'] == 'USA']
print(s)
s.name.str.extract('(.*)')
# Out:
#                                          name   player_id country_id  \
# 1    Aaron Peirsol                             PEIRSAAR01        USA
# 3    Adam Nelson                               NELSOADA01        USA
# 15   Allyson Felix                             FELIXALL01        USA
# 16   Alvin Harrison                            HARRIALV01        USA
# 17   Amanda Beard                              BEARDAMA01        USA
# 18   Amanda Weir                               WEIRAMA01         USA
# 19   Amy van Dyken                             VANDYAMY01        USA
# 25   Angelo Taylor                             TAYLOANG02        USA
# 30   Anthony Ervin                             ERVINANT01        USA
# 32   Antonio Pettigrew                         PETTIANT01        USA
# 40   BJ Bedford                                BEDFOBJ01         USA
# 43   Bernard Williams III                      WILLIBER02        USA
# 46   Brendan Hansen                            HANSEBRE01        USA
# ...

# %%
countries
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-3e0c565b0417> in <module>()
# ----> 1 countries
#
# NameError: name 'countries' is not defined
